# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta

import warnings
warnings.filterwarnings('ignore')


tweets_tesla=pd.read_csv('tweets_tesla.csv', index_col='Date')

data=tweets_tesla[['tweet_hashtags','Change_sign']]

data.rename(columns={'tweet_hashtags': 'text','Change_sign':'target'}, inplace=True)



data['text']=data['text'].str.lower()


# Import the NLTK package and download the necessary data
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# view the stopwords
ENGstopwords = stopwords.words('english')
print(ENGstopwords[0:10])


# Define a function to remove all stopwords
def remove_stopwords(tokenized_text):    
    text = [word for word in tokenized_text if word not in ENGstopwords]
    return text


data['text']=data['text'].apply(lambda x: remove_stopwords(x))




print(data.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\farha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
#                                                          text  target
# Date
# 2011-12-02  [ , e,  , h, e,  , v, l, u, e,  , n,  , h, e, ...       0
# 2011-12-23  [e, l,  ,  , p, n,  , r, e,  , u, !,  , p, e, ...       0
# 2012-01-01  [h, c, k, e,  ,  , e, l,  , c, h, r, g, e,  , ...       1
# 2012-01-07  [e, l,  ,  , g, n, u, r, e,  , e, r, e,  , l, ...       0
# 2012-01-12  [h, e,  , e, x, e, c,  , c, n, f,  , r,  ,  , ...       1

# %%
tweets_tesla
# Out:
#                                                tweet_hashtags  tweet_counts  \
# Date
# 2011-12-02  I made the volume on the Model S   go to 11.  ...             1
# 2011-12-23  Model S options are out! Performance in red an...             1
# 2012-01-01  Hacked my Tesla charge connector on a small is...             1
# 2012-01-07  Model S Signature series sold out as of today ...             2
# 2012-01-12  The exec conf room at Tesla used to be called ...             1
# ...                                                       ...           ...
# 2021-04-12  If you don’t say anything &amp; engage Autopil...             1
# 2021-04-14  Tesla is building up collision repair capabili...             1
# 2021-04-15  Absolutely| True. Ancient times … Had to flip ...             5
# 2021-04-16  I found some footage of the drive  | Stop … In...             5
# 2021-04-17  I was just there, driving Cybertruck around th...             3
#
# ...

# %%
data=tweets_tesla[['tweet_hashtags','Change_sign']]

data.rename(columns={'tweet_hashtags': 'text','Change_sign':'target'}, inplace=True)

data['text']=data['text'].str.lower()

data
# Out:
#                                                          text  target
# Date
# 2011-12-02  i made the volume on the model s   go to 11.  ...       0
# 2011-12-23  model s options are out! performance in red an...       0
# 2012-01-01  hacked my tesla charge connector on a small is...       1
# 2012-01-07  model s signature series sold out as of today ...       0
# 2012-01-12  the exec conf room at tesla used to be called ...       1
# ...                                                       ...     ...
# 2021-04-12  if you don’t say anything &amp; engage autopil...       1
# 2021-04-14  tesla is building up collision repair capabili...       1
# 2021-04-15  absolutely| true. ancient times … had to flip ...       1
# 2021-04-16  i found some footage of the drive  | stop … in...       1
# 2021-04-17  i was just there, driving cybertruck around th...       1
#
# [1036 rows x 2 columns]
